# %%
# Notebook 1 — Data audit and schema alignment
import os
import re
import hashlib
import random
import numpy as np
import pandas as pd
from datetime import datetime

from pandas.core.dtypes.common import pandas_dtype

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

CANONICAL_COLS = [
    "id", "osm_id", "osm_geom_type",
    "osm_tag_key", "osm_tag_value",
    "name", "name_ur", "alt_name",
    "description_raw", "description_final",
    "description_source",
    "wikipedia_title", "wikipedia_url",
    "lat", "lon", "city", "province", "country",
    "language", "dedup_group_id"
]

TIMESTAMP = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S UTC")
print("Seed set. Canonical columns defined.")
# Out:
# Seed set. Canonical columns defined.
# C:\Users\stran\AppData\Local\Temp\ipykernel_3672\1616994383.py:25: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   TIMESTAMP = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S UTC")

# %%
#Utility: Urdu diacritic stripping, normalization, language detection (English/Urdu/Roman Urdu/Mixed)

# %%
import unicodedata

URDU_DIACRITICS = set([
    "\u064b", "\u064c", "\u064d", "\u064e", "\u064f", "\u0650", "\u0651", "\u0652",
    "\u0653", "\u0654", "\u0655", "\u0670"
])

def strip_urdu_diacritics(text: str) -> str:
    if not isinstance(text, str):
        return text
    return "".join(ch for ch in text if ch not in URDU_DIACRITICS)

def normalize_text(s: str) -> str:
    if not isinstance(s, str) or not s:
        return ""
    s = s.replace("\u200c", " ")  # zero-width non-joiner to space
    s = strip_urdu_diacritics(s)
    s = unicodedata.normalize("NFKC", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

# Simple heuristics: Urdu script detection, Roman Urdu cues, English letters
def detect_language_heuristic(s: str) -> str:
    if not isinstance(s, str) or not s.strip():
        return "Unknown"
    has_urdu_script = any("\u0600" <= ch <= "\u06FF" for ch in s)  # Arabic/Urdu block
    has_latin = any("A" <= ch <= "Z" or "a" <= ch <= "z" for ch in s)
    roman_urdu_cues = ["hai", "kia", "kya", "bazar", "masjid", "chowk", "ghar", "khana", "bache", "park", "sadak", "bazaar"]
    has_roman_urdu = any(tok in s.lower() for tok in roman_urdu_cues)

    if has_urdu_script and not has_latin:
        return "Urdu"
    if has_latin and not has_urdu_script:
        return "Roman Urdu" if has_roman_urdu else "English"
    if has_latin and has_urdu_script:
        return "Mixed"
    return "Unknown"

# %%
import unicodedata

URDU_DIACRITICS = set([
    "\u064b", "\u064c", "\u064d", "\u064e", "\u064f", "\u0650", "\u0651", "\u0652",
    "\u0653", "\u0654", "\u0655", "\u0670"
])

def strip_urdu_diacritics(text: str) -> str:
    if not isinstance(text, str):
        return text
    return "".join(ch for ch in text if ch not in URDU_DIACRITICS)

def normalize_text(s: str) -> str:
    if not isinstance(s, str) or not s:
        return ""
    s = s.replace("\u200c", " ")  # zero-width non-joiner to space
    s = strip_urdu_diacritics(s)
    s = unicodedata.normalize("NFKC", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

# Simple heuristics: Urdu script detection, Roman Urdu cues, English letters
def detect_language_heuristic(s: str) -> str:
    if not isinstance(s, str) or not s.strip():
        return "Unknown"
    has_urdu_script = any("\u0600" <= ch <= "\u06FF" for ch in s)  # Arabic/Urdu block
    has_latin = any("A" <= ch <= "Z" or "a" <= ch <= "z" for ch in s)
    roman_urdu_cues = ["hai", "kia", "kya", "bazar", "masjid", "chowk", "ghar", "khana", "bache", "park", "sadak", "bazaar"]
    has_roman_urdu = any(tok in s.lower() for tok in roman_urdu_cues)

    if has_urdu_script and not has_latin:
        return "Urdu"
    if has_latin and not has_urdu_script:
        return "Roman Urdu" if has_roman_urdu else "English"
    if has_latin and has_urdu_script:
        return "Mixed"
    return "Unknown"

# %%
raw_dir = "data/raw"
candidate_files = []
if os.path.isdir(raw_dir):
    for fn in os.listdir(raw_dir):
        if fn.lower().endswith((".csv", ".parquet")):
            candidate_files.append(os.path.join(raw_dir, fn))

df_raw_list = []
for path in candidate_files:
    try:
        if path.endswith(".csv"):
            df_raw_list.append(pd.read_csv(path))
        elif path.endswith(".parquet"):
            df_raw_list.append(pd.read_parquet(path))
    except Exception as e:
        print("Skipping unreadable file:", path, "->", e)

if df_raw_list:
    df_raw = pd.concat(df_raw_list, ignore_index=True)
    source_note = f"Loaded {len(candidate_files)} raw file(s) from data/raw"
else:
    # Toy sample reflecting Islamabad context
    df_raw = pd.DataFrame([
        {
            "id": "toy-1",
            "osm_id": "n1",
            "osm_geom_type": "node",
            "osm_tag_key": "amenity",
            "osm_tag_value": "park",
            "name": "Kids Park F-7",
            "name_ur": "بچوں کا پارک ایف-7",
            "alt_name": "",
            "description_raw": "A quiet park near the F-7 markaz, perfect for kids.",
            "description_source": "toy",
            "wikipedia_title": "",
            "wikipedia_url": "",
            "lat": 33.723, "lon": 73.055,
            "city": "Islamabad", "province": "ICT", "country": "Pakistan",
        },
        {
            "id": "toy-2",
            "osm_id": "w2",
            "osm_geom_type": "way",
            "osm_tag_key": "amenity",
            "osm_tag_value": "place_of_worship",
            "name": "Masjid-e-Quba",
            "name_ur": "مسجد قبا",
            "alt_name": "Quba Mosque",
            "description_raw": "پرانے بازار کے قریب ایک خوبصورت مسجد۔",
            "description_source": "toy",
            "wikipedia_title": "",
            "wikipedia_url": "",
            "lat": 33.706, "lon": 73.039,
            "city": "Islamabad", "province": "ICT", "country": "Pakistan",
        },
        {
            "id": "toy-3",
            "osm_id": "n3",
            "osm_geom_type": "node",
            "osm_tag_key": "shop",
            "osm_tag_value": "mall",
            "name": "Centaurus",
            "name_ur": "سینٹورس",
            "alt_name": "The Centaurus Mall",
            "description_raw": "Famous mall with food court and cinema.",
            "description_source": "toy",
            "wikipedia_title": "The Centaurus",
            "wikipedia_url": "",
            "lat": 33.710, "lon": 73.058,
            "city": "Islamabad", "province": "ICT", "country": "Pakistan",
        }
    ])
    source_note = "Created toy sample (no raw files found)."

print(source_note)
print("Raw shape:", df_raw.shape)
df_raw.head()
# Out:
# Created toy sample (no raw files found).
# Raw shape: (3, 17)
#       id osm_id osm_geom_type osm_tag_key     osm_tag_value           name  \
# 0  toy-1     n1          node     amenity              park  Kids Park F-7
# 1  toy-2     w2           way     amenity  place_of_worship  Masjid-e-Quba
# 2  toy-3     n3          node        shop              mall      Centaurus
#
#               name_ur            alt_name  \
# 0  بچوں کا پارک ایف-7
# 1            مسجد قبا         Quba Mosque
# 2             سینٹورس  The Centaurus Mall
#
#                                      description_raw description_source  \
# 0  A quiet park near the F-7 markaz, perfect for ...                toy
# 1              پرانے بازار کے قریب ایک خوبصورت مسجد۔                toy
# 2            Famous mall with food court and cinema.                toy
#
#   wikipedia_title wikipedia_url     lat     lon       city province   country
# 0                                33.723  73.055  Islamabad      ICT  Pakistan
# 1                                33.706  73.039  Islamabad      ICT  Pakistan
# 2   The Centaurus                33.710  73.058  Islamabad      ICT  Pakistan

# %%
df = df_raw.copy()

# Ensure canonical columns exist; add if missing
for col in CANONICAL_COLS:
    if col not in df.columns:
        df[col] = pd.Series([None] * len(df))

# Prefer description_raw if description_final missing; we'll normalize in next cell
df["description_final"] = df["description_final"].fillna(df["description_raw"])

# Basic types
for num_col in ["lat", "lon"]:
    df[num_col] = pd.to_numeric(df[num_col], errors="coerce")

# Order columns
df = df[CANONICAL_COLS].copy()
print("Aligned to canonical schema with", len(CANONICAL_COLS), "columns.")
df.head()
# Out:
# Aligned to canonical schema with 20 columns.
#       id osm_id osm_geom_type osm_tag_key     osm_tag_value           name  \
# 0  toy-1     n1          node     amenity              park  Kids Park F-7
# 1  toy-2     w2           way     amenity  place_of_worship  Masjid-e-Quba
# 2  toy-3     n3          node        shop              mall      Centaurus
#
#               name_ur            alt_name  \
# 0  بچوں کا پارک ایف-7
# 1            مسجد قبا         Quba Mosque
# 2             سینٹورس  The Centaurus Mall
#
#                                      description_raw  \
# 0  A quiet park near the F-7 markaz, perfect for ...
# 1              پرانے بازار کے قریب ایک خوبصورت مسجد۔
# 2            Famous mall with food court and cinema.
#
#                                    description_final description_source  \
# 0  A quiet park near the F-7 markaz, perfect for ...                toy
# 1              پرانے بازار کے قریب ایک خوبصورت مسجد۔                toy
# 2            Famous mall with food court and cinema.                toy
#
#   wikipedia_title wikipedia_url     lat     lon       city province   country  \
# 0                                33.723  73.055  Islamabad      ICT  Pakistan
# 1                                33.706  73.039  Islamabad      ICT  Pakistan
# 2   The Centaurus                33.710  73.058  Islamabad      ICT  Pakistan
#
#   language dedup_group_id
# 0     None           None
# 1     None           None
# 2     None           None

# %%
df.columns
# Out:
# Index(['id', 'osm_id', 'osm_geom_type', 'osm_tag_key', 'osm_tag_value', 'name',
#        'name_ur', 'alt_name', 'description_raw', 'description_final',
#        'description_source', 'wikipedia_title', 'wikipedia_url', 'lat', 'lon',
#        'city', 'province', 'country', 'language', 'dedup_group_id'],
#       dtype='object')

# %%
text_cols = ["name", "name_ur", "alt_name", "description_raw", "description_final"]

for c in text_cols:
    df[c] = df[c].apply(normalize_text)

# Language detection primarily on description_final; fallback to name
df["language"] = df["description_final"].apply(detect_language_heuristic)
mask_unknown = df["language"].isin(["Unknown", None, ""])
df.loc[mask_unknown, "language"] = df.loc[mask_unknown, "name"].apply(detect_language_heuristic)

print("Language distribution:")
print(df["language"].value_counts(dropna=False))
df.head()
# Out:
# Language distribution:
# language
# Roman Urdu    1
# Urdu          1
# English       1
# Name: count, dtype: int64
#       id osm_id osm_geom_type osm_tag_key     osm_tag_value           name  \
# 0  toy-1     n1          node     amenity              park  Kids Park F-7
# 1  toy-2     w2           way     amenity  place_of_worship  Masjid-e-Quba
# 2  toy-3     n3          node        shop              mall      Centaurus
#
#               name_ur            alt_name  \
# 0  بچوں کا پارک ایف-7
# 1            مسجد قبا         Quba Mosque
# 2             سینٹورس  The Centaurus Mall
#
#                                      description_raw  \
# 0  A quiet park near the F-7 markaz, perfect for ...
# 1              پرانے بازار کے قریب ایک خوبصورت مسجد۔
# 2            Famous mall with food court and cinema.
#
#                                    description_final description_source  \
# 0  A quiet park near the F-7 markaz, perfect for ...                toy
# 1              پرانے بازار کے قریب ایک خوبصورت مسجد۔                toy
# 2            Famous mall with food court and cinema.                toy
#
#   wikipedia_title wikipedia_url     lat     lon       city province   country  \
# 0                                33.723  73.055  Islamabad      ICT  Pakistan
# 1                                33.706  73.039  Islamabad      ICT  Pakistan
# 2   The Centaurus                33.710  73.058  Islamabad      ICT  Pakistan
#
#      language dedup_group_id
# 0  Roman Urdu           None
# 1        Urdu           None
# 2     English           None

# %%
def md5(s: str) -> str:
    if not isinstance(s, str):
        s = str(s)
    return hashlib.md5(s.encode("utf-8")).hexdigest()

# Exact duplicate groups by normalized description_final
df["exact_sig"] = df["description_final"].fillna("").str.lower().apply(md5)

# Near-duplicate: lowercased name within city
df["near_sig"] = (df["city"].fillna("").str.lower() + "||" + df["name"].fillna("").str.lower()).apply(md5)

# Dedup group id: combine exact and near sigs
df["dedup_group_id"] = (df["exact_sig"].str[:8] + "-" + df["near_sig"].str[:8])

# Choose representative row per group: first occurrence
df["rep_rank"] = df.groupby("dedup_group_id").cumcount()
df_rep = df[df["rep_rank"] == 0].copy()

print("Rows before:", len(df), " | after dedup (representatives):", len(df_rep))
df_rep = df_rep.drop(columns=["exact_sig", "near_sig", "rep_rank"])
df_rep.head()
# Out:
# Rows before: 3  | after dedup (representatives): 3
#       id osm_id osm_geom_type osm_tag_key     osm_tag_value           name  \
# 0  toy-1     n1          node     amenity              park  Kids Park F-7
# 1  toy-2     w2           way     amenity  place_of_worship  Masjid-e-Quba
# 2  toy-3     n3          node        shop              mall      Centaurus
#
#               name_ur            alt_name  \
# 0  بچوں کا پارک ایف-7
# 1            مسجد قبا         Quba Mosque
# 2             سینٹورس  The Centaurus Mall
#
#                                      description_raw  \
# 0  A quiet park near the F-7 markaz, perfect for ...
# 1              پرانے بازار کے قریب ایک خوبصورت مسجد۔
# 2            Famous mall with food court and cinema.
#
#                                    description_final description_source  \
# 0  A quiet park near the F-7 markaz, perfect for ...                toy
# 1              پرانے بازار کے قریب ایک خوبصورت مسجد۔                toy
# 2            Famous mall with food court and cinema.                toy
#
#   wikipedia_title wikipedia_url     lat     lon       city province   country  \
# 0                                33.723  73.055  Islamabad      ICT  Pakistan
# 1                                33.706  73.039  Islamabad      ICT  Pakistan
# 2   The Centaurus                33.710  73.058  Islamabad      ICT  Pakistan
#
#      language     dedup_group_id
# 0  Roman Urdu  0dc2b872-da697349
# 1        Urdu  05f94746-e0e4091e
# 2     English  b6ece0a2-82d7bdcf

# %%
os.makedirs("results", exist_ok=True)
os.makedirs("docs/reports", exist_ok=True)

report = {}
report["timestamp"] = TIMESTAMP
report["rows_raw"] = int(len(df))
report["rows_after_dedup"] = int(len(df_rep))

lang_dist = df_rep["language"].value_counts(dropna=False).rename_axis("language").reset_index(name="count")
class_col = df_rep["osm_tag_key"].fillna("") + "=" + df_rep["osm_tag_value"].fillna("")
class_dist = class_col.value_counts(dropna=False).rename_axis("label").reset_index(name="count")

missing = df_rep[["description_final", "lat", "lon", "osm_tag_key", "osm_tag_value"]].isnull().mean().to_dict()

report["language_distribution"] = lang_dist.to_dict(orient="records")
report["class_distribution"] = class_dist.to_dict(orient="records")
report["missing_rates"] = missing

print("Quality summary:")
print(report)

# Save CSV reports
lang_dist.to_csv("results/language_distribution.csv", index=False)
class_dist.to_csv("results/class_distribution.csv", index=False)
print("Saved language_distribution.csv and class_distribution.csv")
# Out:
# Quality summary:
# {'timestamp': '2025-08-15 02:05:05 UTC', 'rows_raw': 3, 'rows_after_dedup': 3, 'language_distribution': [{'language': 'Roman Urdu', 'count': 1}, {'language': 'Urdu', 'count': 1}, {'language': 'English', 'count': 1}], 'class_distribution': [{'label': 'amenity=park', 'count': 1}, {'label': 'amenity=place_of_worship', 'count': 1}, {'label': 'shop=mall', 'count': 1}], 'missing_rates': {'description_final': 0.0, 'lat': 0.0, 'lon': 0.0, 'osm_tag_key': 0.0, 'osm_tag_value': 0.0}}
# Saved language_distribution.csv and class_distribution.csv

# %%
pip install pyarrow fastparquet
# Out:
# Collecting pyarrow
#   Downloading pyarrow-21.0.0-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp313-cp313-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: pandas>=1.5.0 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from fastparquet) (2.3.1)
# Requirement already satisfied: numpy in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from fastparquet) (2.3.2)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl.metadata (681 bytes)
# Requirement already satisfied: fsspec in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from fastparquet) (2025.7.0)
# Requirement already satisfied: packaging in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading pyarrow-21.0.0-cp313-cp313-win_amd64.whl (26.1 MB)
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    - -------------------------------------- 1.0/26.1 MB 4.3 MB/s eta 0:00:06
#    --- ------------------------------------ 2.1/26.1 MB 4.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.9/26.1 MB 4.3 MB/s eta 0:00:06
#    ------ --------------------------------- 3.9/26.1 MB 4.4 MB/s eta 0:00:06
#    ------ --------------------------------- 4.2/26.1 MB 3.9 MB/s eta 0:00:06
#    ------- -------------------------------- 5.0/26.1 MB 3.7 MB/s eta 0:00:06
#    -------- ------------------------------- 5.8/26.1 MB 3.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.6/26.1 MB 3.7 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.3/26.1 MB 3.7 MB/s eta 0:00:06
#    ------------ --------------------------- 8.1/26.1 MB 3.7 MB/s eta 0:00:05
#    ------------- -------------------------- 8.9/26.1 MB 3.7 MB/s eta 0:00:05
#    -------------- ------------------------- 9.7/26.1 MB 3.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 10.7/26.1 MB 3.8 MB/s eta 0:00:05
#    ----------------- ---------------------- 11.5/26.1 MB 3.8 MB/s eta 0:00:04
#    ------------------ --------------------- 12.1/26.1 MB 3.7 MB/s eta 0:00:04
#    ------------------- -------------------- 12.8/26.1 MB 3.7 MB/s eta 0:00:04
#    -------------------- ------------------- 13.4/26.1 MB 3.7 MB/s eta 0:00:04
#    --------------------- ------------------ 14.2/26.1 MB 3.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 14.7/26.1 MB 3.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 15.2/26.1 MB 3.5 MB/s eta 0:00:04
#    ------------------------ --------------- 15.7/26.1 MB 3.5 MB/s eta 0:00:03
#    ------------------------ --------------- 16.3/26.1 MB 3.4 MB/s eta 0:00:03
#    ------------------------- -------------- 16.8/26.1 MB 3.4 MB/s eta 0:00:03
#    -------------------------- ------------- 17.3/26.1 MB 3.3 MB/s eta 0:00:03
#    --------------------------- ------------ 17.8/26.1 MB 3.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.4/26.1 MB 3.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.9/26.1 MB 3.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 19.4/26.1 MB 3.2 MB/s eta 0:00:03
#    ------------------------------ --------- 19.9/26.1 MB 3.2 MB/s eta 0:00:02
#    ------------------------------- -------- 20.4/26.1 MB 3.1 MB/s eta 0:00:02
#    ------------------------------- -------- 20.7/26.1 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 21.2/26.1 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 21.8/26.1 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 22.5/26.1 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 23.1/26.1 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 23.6/26.1 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 24.1/26.1 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 24.9/26.1 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 25.4/26.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  26.0/26.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 26.1/26.1 MB 3.0 MB/s eta 0:00:00
# Downloading fastparquet-2024.11.0-cp313-cp313-win_amd64.whl (673 kB)
#    ---------------------------------------- 0.0/673.3 kB ? eta -:--:--
#    ------------------------------- -------- 524.3/673.3 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 673.3/673.3 kB 2.3 MB/s eta 0:00:00
# Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 3.2 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: pyarrow, cramjam, fastparquet
#
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ---------------------------------------- 0/3 [pyarrow]
#    ------------- -------------------------- 1/3 [cramjam]
#    -------------------------- ------------- 2/3 [fastparquet]
#    -------------------------- ------------- 2/3 [fastparquet]
#    -------------------------- ------------- 2/3 [fastparquet]
#    ---------------------------------------- 3/3 [fastparquet]
#
# Successfully installed cramjam-2.11.0 fastparquet-2024.11.0 pyarrow-21.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
processed_path = "data/processed/descriptions_clean.csv"
processed_parquet = "data/processed/descriptions_clean.parquet"

df_rep.to_csv(processed_path, index=False)
try:
    df_rep.to_parquet(processed_parquet, index=False)
    print("Saved:", processed_path, "and", processed_parquet)
except Exception as e:
    print("Saved:", processed_path, "(parquet skipped ->", e, ")")
# Out:
# Saved: data/processed/descriptions_clean.csv (parquet skipped -> No type extension with name arrow.py_extension_type found )

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\github\repo-phaze7r\geospatial-tagging-thesis\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv('data/processed/descriptions_clean.csv')

# %%
df.head()
# Out:
#       id osm_id osm_geom_type osm_tag_key     osm_tag_value           name  \
# 0  toy-1     n1          node     amenity              park  Kids Park F-7
# 1  toy-2     w2           way     amenity  place_of_worship  Masjid-e-Quba
# 2  toy-3     n3          node        shop              mall      Centaurus
#
#               name_ur            alt_name  \
# 0  بچوں کا پارک ایف-7                 NaN
# 1            مسجد قبا         Quba Mosque
# 2             سینٹورس  The Centaurus Mall
#
#                                      description_raw  \
# 0  A quiet park near the F-7 markaz, perfect for ...
# 1              پرانے بازار کے قریب ایک خوبصورت مسجد۔
# 2            Famous mall with food court and cinema.
#
#                                    description_final description_source  \
# 0  A quiet park near the F-7 markaz, perfect for ...                toy
# 1              پرانے بازار کے قریب ایک خوبصورت مسجد۔                toy
# 2            Famous mall with food court and cinema.                toy
#
#   wikipedia_title  wikipedia_url     lat     lon       city province  \
# 0             NaN            NaN  33.723  73.055  Islamabad      ICT
# 1             NaN            NaN  33.706  73.039  Islamabad      ICT
# 2   The Centaurus            NaN  33.710  73.058  Islamabad      ICT
#
#     country    language     dedup_group_id
# 0  Pakistan  Roman Urdu  0dc2b872-da697349
# 1  Pakistan        Urdu  05f94746-e0e4091e
# 2  Pakistan     English  b6ece0a2-82d7bdcf

# %%
df.columns
# Out:
# Index(['id', 'osm_id', 'osm_geom_type', 'osm_tag_key', 'osm_tag_value', 'name',
#        'name_ur', 'alt_name', 'description_raw', 'description_final',
#        'description_source', 'wikipedia_title', 'wikipedia_url', 'lat', 'lon',
#        'city', 'province', 'country', 'language', 'dedup_group_id'],
#       dtype='object')
